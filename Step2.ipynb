# %% [markdown]
# # 1. Reading and Analysing

# %%
import pyodbc
import pandas as pd

server = 'DELL\\SQLEXPRESS'
database = 'NEHADB'

connection_string = f"DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};Trusted_Connection=yes;"
conn = pyodbc.connect(connection_string)

query = "SELECT * FROM dbo.CS_FUND"
cursor = conn.cursor()
cursor.execute(query)

rows = cursor.fetchall()
columns = [column[0] for column in cursor.description]

df = pd.DataFrame.from_records(rows, columns=columns)

print(df.head())

print("Data Overview:\n", df.head())
print("\nStatistics:\n", df.describe(include='all'))
# Out:
#   ACCT_CD                                          ACCT_NAME ACCT_SHT_NAME  \
# 0       6      FCA Canada Inc. Elected Master Trust (Equity)         k_006
# 1    006x  FCA Canada Inc. Elected Master Trust (Equity)(...          NULL
# 2       7       Canadian Pacific Airline Pilots' Association          NULL
# 3    007x  Canadian Pacific Airline Pilots' Association (...          NULL
# 4    008x                Grosvenor International Canada Ltd.          NULL
#
#   ACCT_TYP_CD PARENT_CHILD_FLAG CRRNCY_CD STATE_CD CNTRY_CD  MKT_VAL  \
# 0           F              NULL       CAD     NULL     NULL      0.0
# 1           F              NULL       CAD     NULL     NULL      NaN
# 2           F              NULL       CAD     NULL     NULL      0.0
# 3           F              NULL       CAD     NULL     NULL      NaN
# 4           F              NULL       CAD     NULL     NULL      NaN
#
#    NET_ASSETS  ...  TARGET_DURATION FACTOR_MODEL_HIERARCHY_CD  \
# 0         0.0  ...             NULL                      NULL
# 1         0.0  ...             NULL                      NULL
# 2         0.0  ...             NULL                      NULL
# 3         0.0  ...             NULL                      NULL
# 4         0.0  ...             NULL                      NULL
#
#    BLOCK_MONITOR_TYPE_CD LAST_MDL_CHANGE_PROCESS_DATE  TARGET_CASH_PCT  \
# 0                   NULL                         NULL             NULL
# 1                   NULL                         NULL             NULL
# 2                   NULL                         NULL             NULL
# 3                   NULL                         NULL             NULL
# 4                   NULL                         NULL             NULL
#
#   DEF_STRATEGY_CHAIN_ID DEF_BENCH_TYPE3 DEF_BENCH_CD3 DEF_BENCH_ID3  \
# 0                  NULL            NULL          NULL          NULL
# 1                  NULL            NULL          NULL          NULL
# 2                  NULL            NULL          NULL          NULL
# 3                  NULL            NULL          NULL          NULL
# 4                  NULL            NULL          NULL          NULL
#
#   STRATEGY_LOT_ENABLED_IND
# 0                        N
# 1                        N
# 2                        N
# 3                        N
# 4                        N
#
# [5 rows x 418 columns]
# Data Overview:
#    ACCT_CD                                          ACCT_NAME ACCT_SHT_NAME  \
# 0       6      FCA Canada Inc. Elected Master Trust (Equity)         k_006
# 1    006x  FCA Canada Inc. Elected Master Trust (Equity)(...          NULL
# 2       7       Canadian Pacific Airline Pilots' Association          NULL
# 3    007x  Canadian Pacific Airline Pilots' Association (...          NULL
# 4    008x                Grosvenor International Canada Ltd.          NULL
#
#   ACCT_TYP_CD PARENT_CHILD_FLAG CRRNCY_CD STATE_CD CNTRY_CD  MKT_VAL  \
# 0           F              NULL       CAD     NULL     NULL      0.0
# 1           F              NULL       CAD     NULL     NULL      NaN
# 2           F              NULL       CAD     NULL     NULL      0.0
# 3           F              NULL       CAD     NULL     NULL      NaN
# 4           F              NULL       CAD     NULL     NULL      NaN
#
#    NET_ASSETS  ...  TARGET_DURATION FACTOR_MODEL_HIERARCHY_CD  \
# 0         0.0  ...             NULL                      NULL
# 1         0.0  ...             NULL                      NULL
# 2         0.0  ...             NULL                      NULL
# 3         0.0  ...             NULL                      NULL
# 4         0.0  ...             NULL                      NULL
#
#    BLOCK_MONITOR_TYPE_CD LAST_MDL_CHANGE_PROCESS_DATE  TARGET_CASH_PCT  \
# 0                   NULL                         NULL             NULL
# 1                   NULL                         NULL             NULL
# 2                   NULL                         NULL             NULL
# 3                   NULL                         NULL             NULL
# 4                   NULL                         NULL             NULL
#
#   DEF_STRATEGY_CHAIN_ID DEF_BENCH_TYPE3 DEF_BENCH_CD3 DEF_BENCH_ID3  \
# 0                  NULL            NULL          NULL          NULL
# 1                  NULL            NULL          NULL          NULL
# 2                  NULL            NULL          NULL          NULL
# 3                  NULL            NULL          NULL          NULL
# 4                  NULL            NULL          NULL          NULL
#
#   STRATEGY_LOT_ENABLED_IND
# 0                        N
# 1                        N
# 2                        N
# 3                        N
# 4                        N
#
# [5 rows x 418 columns]
#
# Statistics:
#         ACCT_CD                    ACCT_NAME ACCT_SHT_NAME ACCT_TYP_CD  \
# count    20593                        20533         20591       20593
# unique   20593                        19506           258           7
# top      x172x  Sun Life Financial Services          NULL           F
# freq         1                           19         20332       18203
# mean       NaN                          NaN           NaN         NaN
# std        NaN                          NaN           NaN         NaN
# min        NaN                          NaN           NaN         NaN
# 25%        NaN                          NaN           NaN         NaN
# 50%        NaN                          NaN           NaN         NaN
# 75%        NaN                          NaN           NaN         NaN
# max        NaN                          NaN           NaN         NaN
#
#        PARENT_CHILD_FLAG CRRNCY_CD STATE_CD CNTRY_CD       MKT_VAL  \
# count              20593     20593    20593    20593  1.489900e+04
# unique                 1        12        5        1           NaN
# top                 NULL       CAD     NULL     NULL           NaN
# freq               20593     18830    20585    20593           NaN
# mean                 NaN       NaN      NaN      NaN  2.081221e+08
# std                  NaN       NaN      NaN      NaN  3.141240e+09
# min                  NaN       NaN      NaN      NaN -7.600930e+08
# 25%                  NaN       NaN      NaN      NaN  0.000000e+00
# 50%                  NaN       NaN      NaN      NaN  0.000000e+00
# 75%                  NaN       NaN      NaN      NaN  3.181554e+05
# max                  NaN       NaN      NaN      NaN  1.703596e+11
#
#           NET_ASSETS  ...  TARGET_DURATION FACTOR_MODEL_HIERARCHY_CD  \
# count   2.039000e+04  ...            20593                     20593
# unique           NaN  ...                1                         1
# top              NaN  ...             NULL                      NULL
# freq             NaN  ...            20593                     20593
# mean    4.435765e+06  ...              NaN                       NaN
# std     1.264980e+08  ...              NaN                       NaN
# min    -7.600930e+08  ...              NaN                       NaN
# 25%     0.000000e+00  ...              NaN                       NaN
# 50%     0.000000e+00  ...              NaN                       NaN
# 75%     0.000000e+00  ...              NaN                       NaN
# max     1.064595e+10  ...              NaN                       NaN
#
#         BLOCK_MONITOR_TYPE_CD LAST_MDL_CHANGE_PROCESS_DATE  TARGET_CASH_PCT  \
# count                   20593                        20593            20593
# unique                      1                            1                1
# top                      NULL                         NULL             NULL
# freq                    20593                        20593            20593
# mean                      NaN                          NaN              NaN
# std                       NaN                          NaN              NaN
# min                       NaN                          NaN              NaN
# 25%                       NaN                          NaN              NaN
# 50%                       NaN                          NaN              NaN
# 75%                       NaN                          NaN              NaN
# max                       NaN                          NaN              NaN
#
#        DEF_STRATEGY_CHAIN_ID DEF_BENCH_TYPE3 DEF_BENCH_CD3 DEF_BENCH_ID3  \
# count                  20593           20593         20593         20593
# unique                     1               1             1             1
# top                     NULL            NULL          NULL          NULL
# freq                   20593           20593         20593         20593
# mean                     NaN             NaN           NaN           NaN
# std                      NaN             NaN           NaN           NaN
# min                      NaN             NaN           NaN           NaN
# 25%                      NaN             NaN           NaN           NaN
# 50%                      NaN             NaN           NaN           NaN
# 75%                      NaN             NaN           NaN           NaN
# max                      NaN             NaN           NaN           NaN
#
#        STRATEGY_LOT_ENABLED_IND
# count                     20593
# unique                        1
# top                           N
# freq                      20593
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
# [11 rows x 418 columns]

# %% [markdown]
# # 2. Datatype Suggestion

# %%
dtype_mapping = {
    'int64': 'INT',
    'float64': 'FLOAT',
    'object': 'VARCHAR(MAX)',  # String type
    'datetime64[ns]': 'DATETIME',
    'bool': 'BIT'
}

suggested_dtypes = {col: dtype_mapping[str(df[col].dtype)] for col in df.columns}

print("Suggested Data Types for SQL Server:")
print(suggested_dtypes)
# Out:
# Suggested Data Types for SQL Server:
# {'ACCT_CD': 'VARCHAR(MAX)', 'ACCT_NAME': 'VARCHAR(MAX)', 'ACCT_SHT_NAME': 'VARCHAR(MAX)', 'ACCT_TYP_CD': 'VARCHAR(MAX)', 'PARENT_CHILD_FLAG': 'VARCHAR(MAX)', 'CRRNCY_CD': 'VARCHAR(MAX)', 'STATE_CD': 'VARCHAR(MAX)', 'CNTRY_CD': 'VARCHAR(MAX)', 'MKT_VAL': 'FLOAT', 'NET_ASSETS': 'FLOAT', 'TOT_ASSETS': 'FLOAT', 'FUND_SHRS_OUTST': 'VARCHAR(MAX)', 'TOT_COST': 'FLOAT', 'NET_CASH': 'VARCHAR(MAX)', 'TOT_INVSTMNTS': 'FLOAT', 'NET_FUNDS_AVAIL': 'VARCHAR(MAX)', 'LIABILITIES': 'VARCHAR(MAX)', 'AMRTZD_COST': 'VARCHAR(MAX)', 'AVG_COST': 'VARCHAR(MAX)', 'OTH_ASSET': 'VARCHAR(MAX)', 'DIV_RECEIVED': 'VARCHAR(MAX)', 'INT_RECEIVED': 'VARCHAR(MAX)', 'CNTRBS': 'VARCHAR(MAX)', 'PMNTS': 'VARCHAR(MAX)', 'TRANSFERS': 'VARCHAR(MAX)', 'CASH_BAL_SOD': 'VARCHAR(MAX)', 'RECVB_SEC_SOLD': 'VARCHAR(MAX)', 'PAYBL_SEC_PURCH': 'VARCHAR(MAX)', 'RECVB_FUND_SHRS_SOLD': 'VARCHAR(MAX)', 'PAYBL_FUND_SHRS_LIQD': 'VARCHAR(MAX)', 'DIV_RCVBLE': 'VARCHAR(MAX)', 'ACCRUED_INT_INCM': 'VARCHAR(MAX)', 'ACCRUED_EXP_INCM': 'VARCHAR(MAX)', 'DIV_PAYBL': 'VARCHAR(MAX)', 'OTH_LIAB': 'VARCHAR(MAX)', 'EQTY_ACCT': 'VARCHAR(MAX)', 'SYST_OF_REFERENCE': 'VARCHAR(MAX)', 'NEXPERT_INST': 'FLOAT', 'THEME_1': 'VARCHAR(MAX)', 'THEME_2': 'VARCHAR(MAX)', 'THEME_3': 'VARCHAR(MAX)', 'LOT_SIZE': 'VARCHAR(MAX)', 'ALLOW_BUY': 'VARCHAR(MAX)', 'ALLOW_SELL': 'VARCHAR(MAX)', 'ALLOW_NEG_CASH': 'BIT', 'MANAGER': 'VARCHAR(MAX)', 'MODEL_PRIV': 'VARCHAR(MAX)', 'DEFAULT_MODEL_CD': 'VARCHAR(MAX)', 'START_BATCH_VIOL': 'FLOAT', 'SHAW_MANAGER_CD': 'VARCHAR(MAX)', 'SHAW_CLASS_CD': 'VARCHAR(MAX)', 'CRD_LOCK': 'VARCHAR(MAX)', 'ERISA_ELIGIBLE': 'VARCHAR(MAX)', 'INDEX_SEC_ID': 'VARCHAR(MAX)', 'COMPLIANCE_TOLERANCE': 'FLOAT', 'APPLY_GUIDELINES': 'VARCHAR(MAX)', 'GAIN_LOSS_SENSITIVE': 'VARCHAR(MAX)', 'SHORT_SHORT_GAINS': 'VARCHAR(MAX)', 'GROSS_INCOME': 'VARCHAR(MAX)', 'TAX_LOT_SELL_CNVTN': 'VARCHAR(MAX)', 'BANK_ACCT_NUM': 'VARCHAR(MAX)', 'CUSTODIAN_CD': 'VARCHAR(MAX)', 'DEFAULT_GRP_CD': 'VARCHAR(MAX)', 'INCL_ACCRD_INTEREST': 'VARCHAR(MAX)', 'CUR_MKT_VAL': 'FLOAT', 'CUR_INVESTED': 'VARCHAR(MAX)', 'LAST_REPRICE_DATE': 'VARCHAR(MAX)', 'DISC_ACCRUAL_CNVTN': 'VARCHAR(MAX)', 'ACTIVE': 'VARCHAR(MAX)', 'INTERESTED_PARTY1_CD': 'VARCHAR(MAX)', 'INTERESTED_PARTY2_CD': 'VARCHAR(MAX)', 'INTERESTED_PARTY3_CD': 'VARCHAR(MAX)', 'DEFAULT_TMP_ACCT': 'VARCHAR(MAX)', 'INACTIVE': 'BIT', 'USR_CLASS_CD_1': 'VARCHAR(MAX)', 'USR_CLASS_CD_2': 'VARCHAR(MAX)', 'USR_CLASS_CD_3': 'VARCHAR(MAX)', 'USR_CLASS_CD_4': 'VARCHAR(MAX)', 'MKT_VAL_SOD': 'VARCHAR(MAX)', 'OASYS_ACCT_CD': 'VARCHAR(MAX)', 'FUND_ACCT': 'VARCHAR(MAX)', 'OMNIBUS_ACCT_CD': 'VARCHAR(MAX)', 'ALLOW_AUTOFX': 'VARCHAR(MAX)', 'ROTATION_CD': 'VARCHAR(MAX)', 'ROTATION_SEQ': 'VARCHAR(MAX)', 'AUTH_GROUP': 'VARCHAR(MAX)', 'AUTH_NUM': 'VARCHAR(MAX)', 'DEFAULT_SPECIAL_INST': 'VARCHAR(MAX)', 'COMP_BID_REQ': 'VARCHAR(MAX)', 'MAX_ISSUER_HOLDING': 'VARCHAR(MAX)', 'INC_TAX_RATE': 'VARCHAR(MAX)', 'CG_TAX_RATE': 'VARCHAR(MAX)', 'UDF_FLOAT1': 'VARCHAR(MAX)', 'UDF_FLOAT2': 'VARCHAR(MAX)', 'UDF_FLOAT3': 'VARCHAR(MAX)', 'UDF_FLOAT4': 'VARCHAR(MAX)', 'UDF_DATE1': 'VARCHAR(MAX)', 'UDF_DATE2': 'VARCHAR(MAX)', 'UDF_CHAR1': 'VARCHAR(MAX)', 'UDF_CHAR2': 'VARCHAR(MAX)', 'UDF_CHAR3': 'VARCHAR(MAX)', 'UDF_CHAR4': 'VARCHAR(MAX)', 'YTD_GL_SHORT_TERM': 'FLOAT', 'YTD_GL_LONG_TERM': 'FLOAT', 'INTRADAY_GL_SHORT_TERM': 'FLOAT', 'INTRADAY_GL_LONG_TERM': 'FLOAT', 'UPDATE_IN_PROGRESS': 'FLOAT', 'UPDATE_SEQNO': 'FLOAT', 'UDF_FLOAT5': 'FLOAT', 'UDF_FLOAT6': 'FLOAT', 'UDF_FLOAT7': 'FLOAT', 'UDF_FLOAT8': 'VARCHAR(MAX)', 'UDF_FLOAT9': 'FLOAT', 'UDF_FLOAT10': 'FLOAT', 'UDF_FLOAT11': 'VARCHAR(MAX)', 'UDF_FLOAT12': 'VARCHAR(MAX)', 'UDF_FLOAT13': 'VARCHAR(MAX)', 'UDF_FLOAT14': 'VARCHAR(MAX)', 'UDF_FLOAT15': 'VARCHAR(MAX)', 'UDF_FLOAT16': 'FLOAT', 'UDF_FLOAT17': 'VARCHAR(MAX)', 'UDF_FLOAT18': 'VARCHAR(MAX)', 'UDF_FLOAT19': 'VARCHAR(MAX)', 'UDF_DATE3': 'VARCHAR(MAX)', 'UDF_DATE4': 'VARCHAR(MAX)', 'UDF_DATE5': 'VARCHAR(MAX)', 'UDF_DATE6': 'VARCHAR(MAX)', 'UDF_DATE7': 'VARCHAR(MAX)', 'UDF_DATE8': 'VARCHAR(MAX)', 'UDF_DATE9': 'VARCHAR(MAX)', ' ...

# %% [markdown]
# # 3. Dropping NULL Columns

# %%
import pandas as pd

columns_to_keep = []

for column in df.columns:
    non_null_values = df[column].dropna().tolist()
    if non_null_values:  # Check if the list is not empty
        columns_to_keep.append(column)
        print(f"{column}: {non_null_values}")
        
df_cleaned = df[columns_to_keep]
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd
import numpy as np

df = df.replace("", np.nan)
df_cleaned = df.dropna(axis=1, how='all')
print("Columns kept:", df_cleaned.columns.tolist())
# Out:
# Columns kept: ['ACCT_CD', 'ACCT_NAME', 'ACCT_SHT_NAME', 'ACCT_TYP_CD', 'PARENT_CHILD_FLAG', 'CRRNCY_CD', 'STATE_CD', 'CNTRY_CD', 'MKT_VAL', 'NET_ASSETS', 'TOT_ASSETS', 'FUND_SHRS_OUTST', 'TOT_COST', 'NET_CASH', 'TOT_INVSTMNTS', 'NET_FUNDS_AVAIL', 'LIABILITIES', 'AMRTZD_COST', 'AVG_COST', 'OTH_ASSET', 'DIV_RECEIVED', 'INT_RECEIVED', 'CNTRBS', 'PMNTS', 'TRANSFERS', 'CASH_BAL_SOD', 'RECVB_SEC_SOLD', 'PAYBL_SEC_PURCH', 'RECVB_FUND_SHRS_SOLD', 'PAYBL_FUND_SHRS_LIQD', 'DIV_RCVBLE', 'ACCRUED_INT_INCM', 'ACCRUED_EXP_INCM', 'DIV_PAYBL', 'OTH_LIAB', 'EQTY_ACCT', 'SYST_OF_REFERENCE', 'NEXPERT_INST', 'THEME_1', 'THEME_2', 'THEME_3', 'LOT_SIZE', 'ALLOW_BUY', 'ALLOW_SELL', 'ALLOW_NEG_CASH', 'MANAGER', 'MODEL_PRIV', 'DEFAULT_MODEL_CD', 'START_BATCH_VIOL', 'SHAW_MANAGER_CD', 'SHAW_CLASS_CD', 'CRD_LOCK', 'ERISA_ELIGIBLE', 'INDEX_SEC_ID', 'COMPLIANCE_TOLERANCE', 'APPLY_GUIDELINES', 'GAIN_LOSS_SENSITIVE', 'SHORT_SHORT_GAINS', 'GROSS_INCOME', 'TAX_LOT_SELL_CNVTN', 'BANK_ACCT_NUM', 'CUSTODIAN_CD', 'DEFAULT_GRP_CD', 'INCL_ACCRD_INTEREST', 'CUR_MKT_VAL', 'CUR_INVESTED', 'LAST_REPRICE_DATE', 'DISC_ACCRUAL_CNVTN', 'ACTIVE', 'INTERESTED_PARTY1_CD', 'INTERESTED_PARTY2_CD', 'INTERESTED_PARTY3_CD', 'DEFAULT_TMP_ACCT', 'INACTIVE', 'USR_CLASS_CD_1', 'USR_CLASS_CD_2', 'USR_CLASS_CD_3', 'USR_CLASS_CD_4', 'MKT_VAL_SOD', 'OASYS_ACCT_CD', 'FUND_ACCT', 'OMNIBUS_ACCT_CD', 'ALLOW_AUTOFX', 'ROTATION_CD', 'ROTATION_SEQ', 'AUTH_GROUP', 'AUTH_NUM', 'DEFAULT_SPECIAL_INST', 'COMP_BID_REQ', 'MAX_ISSUER_HOLDING', 'INC_TAX_RATE', 'CG_TAX_RATE', 'UDF_FLOAT1', 'UDF_FLOAT2', 'UDF_FLOAT3', 'UDF_FLOAT4', 'UDF_DATE1', 'UDF_DATE2', 'UDF_CHAR1', 'UDF_CHAR2', 'UDF_CHAR3', 'UDF_CHAR4', 'YTD_GL_SHORT_TERM', 'YTD_GL_LONG_TERM', 'INTRADAY_GL_SHORT_TERM', 'INTRADAY_GL_LONG_TERM', 'UPDATE_IN_PROGRESS', 'UPDATE_SEQNO', 'UDF_FLOAT5', 'UDF_FLOAT6', 'UDF_FLOAT7', 'UDF_FLOAT8', 'UDF_FLOAT9', 'UDF_FLOAT10', 'UDF_FLOAT11', 'UDF_FLOAT12', 'UDF_FLOAT13', 'UDF_FLOAT14', 'UDF_FLOAT15', 'UDF_FLOAT16', 'UDF_FLOAT17', 'UDF_FLOAT18', 'UDF_FLOAT19', 'UDF_DATE3', 'UDF_DATE4', 'UDF_DATE5', 'UDF_DATE6', 'UDF_DATE7', 'UDF_DATE8', 'UDF_DATE9', 'UDF_DATE10', 'UDF_DATE11', 'UDF_DATE12', 'UDF_CHAR5', 'UDF_CHAR6', 'UDF_CHAR7', 'UDF_CHAR8', 'UDF_CHAR9', 'UDF_CHAR10', 'UDF_CHAR11', 'UDF_CHAR12', 'UDF_CHAR13', 'UDF_CHAR14', 'UDF_CHAR15', 'UDF_CHAR16', 'UDF_CHAR17', 'UDF_CHAR18', 'UDF_CHAR19', 'UDF_FLOAT1_PREV', 'UDF_FLOAT2_PREV', 'UDF_FLOAT3_PREV', 'UDF_FLOAT4_PREV', 'UDF_FLOAT5_PREV', 'UDF_FLOAT6_PREV', 'UDF_FLOAT7_PREV', 'UDF_FLOAT8_PREV', 'UDF_FLOAT9_PREV', 'UDF_FLOAT10_PREV', 'UDF_FLOAT11_PREV', 'UDF_FLOAT12_PREV', 'UDF_FLOAT13_PREV', 'UDF_FLOAT14_PREV', 'UDF_FLOAT15_PREV', 'UDF_FLOAT16_PREV', 'UDF_FLOAT17_PREV', 'UDF_FLOAT18_PREV', 'UDF_FLOAT19_PREV', 'MKT_VAL_PREV', 'NET_ASSETS_PREV', 'TOT_ASSETS_PREV', 'TOT_COST_PREV', 'GROSS_INCOME_PREV', 'CATEGORY1', 'CATEGORY2', 'CATEGORY3', 'CPL_BATCH_RUNTIME', 'MDL_TYP_IND', 'MDL_BENCH_ACCT_CD', 'DEF_BENCH_CD', 'DEF_HEDGE_MDL_CD', 'DEF_HEDGE_BENCH_CD', 'DEF_MDL_ID', 'DEF_BENCH_ID', 'DEF_HEDGE_MDL_ID', 'DEF_HEDGE_BENCH_ID', 'MAG_IND', 'CFWD_CLOSE_CPARTY_IND', 'CFWD_NEW_CPARTY_IND', 'AUTO_CFWD_IND', 'USE_SETTLE_DATE_BAL_IND', 'DEF_MDL_TYPE', 'DEF_BENCH_TYPE', 'DEF_HEDGE_MDL_TYPE', 'DEF_HEDGE_BENCH_TYPE', 'DM_IND', 'DEF_FWD_DAYS_IND', 'DEF_FWD_DATE', 'DEF_FWD_DAYS', 'DEF_MDL_REM_IND', 'VIEW_ID', 'SLEEVE_TYPE', 'CROSS_EXT_ACCT_CD', 'CROSS_GRP_ACCT_CD', 'CROSS_INT_ACCT_CD', 'CROSS_MAG_ACCT_CD', 'MDL_QTY_BASED_IND', 'MULT_MDL_IND', 'MULT_MDL_NORM_IND', 'EXCH_LIST_CD', 'INV_CLASS_CD', 'BLOCK_ORDER_IND', 'TEN_MIN_CHECK_IND', 'GRP_TYPE_CD', 'TAX_LOT_PROC_IND', 'RECORD_VERSION', 'FEE_PAYMT_IND', 'BUNDLED_FEE_IND', 'PMA_FOOTNOTE', 'PMA_INCPTN_DATE', 'PMA_ACCT_TOT_RET_APPROX', 'MDL_ANALYTIC_TYPE', 'REPRICE_IND', 'PMA_DATA_FREQ', 'PMA_MGMT_FEE_BASIS', 'REBAL_FREQ_CD', 'NEXT_REBAL_DATE', 'LAST_UPD_DATE', 'LAST_UPD_USER', 'COMMENTS', 'BASKET_TYP_CD', 'NOTNL_FREEZE_IND', 'CREATE_DATE', 'CLOSE_DATE', 'FUT_BROKER_IND', 'PMA_ATTR_METHOD_FI', 'PMA_COMMENT', 'PMA_ATTR_METHOD_EQUITY', 'PMA_TA ...

# %% [markdown]
# # 4. Finding Duplicates and dropping them

# %%
if 'ACCT_CD' in df.columns:
    print("\nAnalyzing 'ACCT_CD' column for duplicates...")
    
    duplicate_count = df['ACCT_CD'].duplicated().sum()
    print(f"Number of duplicate entries in 'ACCT_CD': {duplicate_count}")
    
    if duplicate_count > 0:
        df_cleaned = df.drop_duplicates(subset='ACCT_CD', keep='first').reset_index(drop=True)
        print("\nDuplicates removed. Altered DataFrame:")
        print(df_cleaned.head())
    else:
        print("\nNo duplicates found in 'ACCT_CD'.")
else:
    print("\n'ACCT_CD' column not found in the DataFrame.")
# Out:
# Analyzing 'ACCT_CD' column for duplicates...
# Number of duplicate entries in 'ACCT_CD': 0
#
# No duplicates found in 'ACCT_CD'.

# %%
df_cleaned
# Out:
#       ACCT_CD                                          ACCT_NAME  \
# 0           6      FCA Canada Inc. Elected Master Trust (Equity)
# 1        006x  FCA Canada Inc. Elected Master Trust (Equity)(...
# 2           7       Canadian Pacific Airline Pilots' Association
# 3        007x  Canadian Pacific Airline Pilots' Association (...
# 4        008x                Grosvenor International Canada Ltd.
# ...       ...                                                ...
# 20588  x0145x              Gestion Marc Valois Inc. USD (Closed)
# 20589   x014x              Gestion Marc Valois Inc. CAD (Closed)
# 20590     x10                          Steelworkers Pension Plan
# 20591   x168x           Boilermakers Private Placements (Closed)
# 20592   x172x                 Ironworkers Local 97 Ventures West
#
#       ACCT_SHT_NAME ACCT_TYP_CD PARENT_CHILD_FLAG CRRNCY_CD STATE_CD CNTRY_CD  \
# 0             k_006           F              NULL       CAD     NULL     NULL
# 1              NULL           F              NULL       CAD     NULL     NULL
# 2              NULL           F              NULL       CAD     NULL     NULL
# 3              NULL           F              NULL       CAD     NULL     NULL
# 4              NULL           F              NULL       CAD     NULL     NULL
# ...             ...         ...               ...       ...      ...      ...
# 20588          NULL           F              NULL       USD     NULL     NULL
# 20589          NULL           F              NULL       CAD     NULL     NULL
# 20590          NULL           F              NULL       CAD     NULL     NULL
# 20591          NULL           F              NULL       CAD     NULL     NULL
# 20592          NULL           F              NULL       CAD     NULL     NULL
#
#           MKT_VAL  NET_ASSETS  ...  TARGET_DURATION FACTOR_MODEL_HIERARCHY_CD  \
# 0             0.0      0.0000  ...             NULL                      NULL
# 1             NaN      0.0000  ...             NULL                      NULL
# 2             0.0      0.0000  ...             NULL                      NULL
# 3             NaN      0.0000  ...             NULL                      NULL
# 4             NaN      0.0000  ...             NULL                      NULL
# ...           ...         ...  ...              ...                       ...
# 20588         NaN      0.0000  ...             NULL                      NULL
# 20589         NaN      0.0000  ...             NULL                      NULL
# 20590  57957192.0      0.0025  ...             NULL                      NULL
# 20591         NaN      0.0000  ...             NULL                      NULL
# 20592         NaN      0.0000  ...             NULL                      NULL
#
#        BLOCK_MONITOR_TYPE_CD LAST_MDL_CHANGE_PROCESS_DATE  TARGET_CASH_PCT  \
# 0                       NULL                         NULL             NULL
# 1                       NULL                         NULL             NULL
# 2                       NULL                         NULL             NULL
# 3                       NULL                         NULL             NULL
# 4                       NULL                         NULL             NULL
# ...                      ...                          ...              ...
# 20588                   NULL                         NULL             NULL
# 20589                   NULL                         NULL             NULL
# 20590                   NULL                         NULL             NULL
# 20591                   NULL                         NULL             NULL
# 20592                   NULL                         NULL             NULL
#
#       DEF_STRATEGY_CHAIN_ID DEF_BENCH_TYPE3 DEF_BENCH_CD3 DEF_BENCH_ID3  \
# 0                      NULL            NULL          NULL          NULL
# 1                      NULL            NULL          NULL          NULL
# 2                      NULL            NULL          NULL          NULL
# 3                      NULL            NULL          NULL          NULL
# 4                      NULL            NULL          NULL          NULL
# ...                     ...             ...           ...           ...
# 20588                  NULL            NULL          NULL          NULL
# 20589                  NULL            NULL          NULL          NULL
# 20590                  NULL            NULL          NULL          NULL
# 20591                  NULL            NULL          NULL          NULL
# 20592                  NULL            NULL          NULL          NULL
#
#       STRATEGY_LOT_ENABLED_IND
# 0                            N
# 1                            N
# 2                            N
# 3                            N
# 4                            N
# ...                        ...
# 20588                        N
# 20589                        N
# 20590                        N
# 20591                        N
# 20592                        N
#
# [20593 rows x 418 columns]

# %% [markdown]
# # 5. Changing relevant datatypes

# %%
import pandas as pd

def suggest_datatype(series):
    if pd.api.types.is_integer_dtype(series):
        return 'INTEGER'
    elif pd.api.types.is_float_dtype(series):
        return 'FLOAT'
    elif pd.api.types.is_datetime64_any_dtype(series):
        return 'DATETIME'
    elif pd.api.types.is_string_dtype(series):
        return 'VARCHAR(MAX)'
    else:
        return 'VARCHAR(MAX)'
        
columns_in_df = df_cleaned.columns

data_types = {col: suggest_datatype(df_cleaned[col]) for col in columns_in_df}
print(data_types)
# Out:
# {'ACCT_CD': 'VARCHAR(MAX)', 'ACCT_NAME': 'VARCHAR(MAX)', 'ACCT_SHT_NAME': 'VARCHAR(MAX)', 'ACCT_TYP_CD': 'VARCHAR(MAX)', 'PARENT_CHILD_FLAG': 'VARCHAR(MAX)', 'CRRNCY_CD': 'VARCHAR(MAX)', 'STATE_CD': 'VARCHAR(MAX)', 'CNTRY_CD': 'VARCHAR(MAX)', 'MKT_VAL': 'FLOAT', 'NET_ASSETS': 'FLOAT', 'TOT_ASSETS': 'FLOAT', 'FUND_SHRS_OUTST': 'VARCHAR(MAX)', 'TOT_COST': 'FLOAT', 'NET_CASH': 'VARCHAR(MAX)', 'TOT_INVSTMNTS': 'FLOAT', 'NET_FUNDS_AVAIL': 'VARCHAR(MAX)', 'LIABILITIES': 'VARCHAR(MAX)', 'AMRTZD_COST': 'VARCHAR(MAX)', 'AVG_COST': 'VARCHAR(MAX)', 'OTH_ASSET': 'VARCHAR(MAX)', 'DIV_RECEIVED': 'VARCHAR(MAX)', 'INT_RECEIVED': 'VARCHAR(MAX)', 'CNTRBS': 'VARCHAR(MAX)', 'PMNTS': 'VARCHAR(MAX)', 'TRANSFERS': 'VARCHAR(MAX)', 'CASH_BAL_SOD': 'VARCHAR(MAX)', 'RECVB_SEC_SOLD': 'VARCHAR(MAX)', 'PAYBL_SEC_PURCH': 'VARCHAR(MAX)', 'RECVB_FUND_SHRS_SOLD': 'VARCHAR(MAX)', 'PAYBL_FUND_SHRS_LIQD': 'VARCHAR(MAX)', 'DIV_RCVBLE': 'VARCHAR(MAX)', 'ACCRUED_INT_INCM': 'VARCHAR(MAX)', 'ACCRUED_EXP_INCM': 'VARCHAR(MAX)', 'DIV_PAYBL': 'VARCHAR(MAX)', 'OTH_LIAB': 'VARCHAR(MAX)', 'EQTY_ACCT': 'VARCHAR(MAX)', 'SYST_OF_REFERENCE': 'VARCHAR(MAX)', 'NEXPERT_INST': 'FLOAT', 'THEME_1': 'VARCHAR(MAX)', 'THEME_2': 'VARCHAR(MAX)', 'THEME_3': 'VARCHAR(MAX)', 'LOT_SIZE': 'VARCHAR(MAX)', 'ALLOW_BUY': 'VARCHAR(MAX)', 'ALLOW_SELL': 'VARCHAR(MAX)', 'ALLOW_NEG_CASH': 'VARCHAR(MAX)', 'MANAGER': 'VARCHAR(MAX)', 'MODEL_PRIV': 'VARCHAR(MAX)', 'DEFAULT_MODEL_CD': 'VARCHAR(MAX)', 'START_BATCH_VIOL': 'FLOAT', 'SHAW_MANAGER_CD': 'VARCHAR(MAX)', 'SHAW_CLASS_CD': 'VARCHAR(MAX)', 'CRD_LOCK': 'VARCHAR(MAX)', 'ERISA_ELIGIBLE': 'VARCHAR(MAX)', 'INDEX_SEC_ID': 'VARCHAR(MAX)', 'COMPLIANCE_TOLERANCE': 'FLOAT', 'APPLY_GUIDELINES': 'VARCHAR(MAX)', 'GAIN_LOSS_SENSITIVE': 'VARCHAR(MAX)', 'SHORT_SHORT_GAINS': 'VARCHAR(MAX)', 'GROSS_INCOME': 'VARCHAR(MAX)', 'TAX_LOT_SELL_CNVTN': 'VARCHAR(MAX)', 'BANK_ACCT_NUM': 'VARCHAR(MAX)', 'CUSTODIAN_CD': 'VARCHAR(MAX)', 'DEFAULT_GRP_CD': 'VARCHAR(MAX)', 'INCL_ACCRD_INTEREST': 'VARCHAR(MAX)', 'CUR_MKT_VAL': 'FLOAT', 'CUR_INVESTED': 'VARCHAR(MAX)', 'LAST_REPRICE_DATE': 'VARCHAR(MAX)', 'DISC_ACCRUAL_CNVTN': 'VARCHAR(MAX)', 'ACTIVE': 'VARCHAR(MAX)', 'INTERESTED_PARTY1_CD': 'VARCHAR(MAX)', 'INTERESTED_PARTY2_CD': 'VARCHAR(MAX)', 'INTERESTED_PARTY3_CD': 'VARCHAR(MAX)', 'DEFAULT_TMP_ACCT': 'VARCHAR(MAX)', 'INACTIVE': 'VARCHAR(MAX)', 'USR_CLASS_CD_1': 'VARCHAR(MAX)', 'USR_CLASS_CD_2': 'VARCHAR(MAX)', 'USR_CLASS_CD_3': 'VARCHAR(MAX)', 'USR_CLASS_CD_4': 'VARCHAR(MAX)', 'MKT_VAL_SOD': 'VARCHAR(MAX)', 'OASYS_ACCT_CD': 'VARCHAR(MAX)', 'FUND_ACCT': 'VARCHAR(MAX)', 'OMNIBUS_ACCT_CD': 'VARCHAR(MAX)', 'ALLOW_AUTOFX': 'VARCHAR(MAX)', 'ROTATION_CD': 'VARCHAR(MAX)', 'ROTATION_SEQ': 'VARCHAR(MAX)', 'AUTH_GROUP': 'VARCHAR(MAX)', 'AUTH_NUM': 'VARCHAR(MAX)', 'DEFAULT_SPECIAL_INST': 'VARCHAR(MAX)', 'COMP_BID_REQ': 'VARCHAR(MAX)', 'MAX_ISSUER_HOLDING': 'VARCHAR(MAX)', 'INC_TAX_RATE': 'VARCHAR(MAX)', 'CG_TAX_RATE': 'VARCHAR(MAX)', 'UDF_FLOAT1': 'VARCHAR(MAX)', 'UDF_FLOAT2': 'VARCHAR(MAX)', 'UDF_FLOAT3': 'VARCHAR(MAX)', 'UDF_FLOAT4': 'VARCHAR(MAX)', 'UDF_DATE1': 'VARCHAR(MAX)', 'UDF_DATE2': 'VARCHAR(MAX)', 'UDF_CHAR1': 'VARCHAR(MAX)', 'UDF_CHAR2': 'VARCHAR(MAX)', 'UDF_CHAR3': 'VARCHAR(MAX)', 'UDF_CHAR4': 'VARCHAR(MAX)', 'YTD_GL_SHORT_TERM': 'FLOAT', 'YTD_GL_LONG_TERM': 'FLOAT', 'INTRADAY_GL_SHORT_TERM': 'FLOAT', 'INTRADAY_GL_LONG_TERM': 'FLOAT', 'UPDATE_IN_PROGRESS': 'FLOAT', 'UPDATE_SEQNO': 'FLOAT', 'UDF_FLOAT5': 'FLOAT', 'UDF_FLOAT6': 'FLOAT', 'UDF_FLOAT7': 'FLOAT', 'UDF_FLOAT8': 'VARCHAR(MAX)', 'UDF_FLOAT9': 'FLOAT', 'UDF_FLOAT10': 'FLOAT', 'UDF_FLOAT11': 'VARCHAR(MAX)', 'UDF_FLOAT12': 'VARCHAR(MAX)', 'UDF_FLOAT13': 'VARCHAR(MAX)', 'UDF_FLOAT14': 'VARCHAR(MAX)', 'UDF_FLOAT15': 'VARCHAR(MAX)', 'UDF_FLOAT16': 'FLOAT', 'UDF_FLOAT17': 'VARCHAR(MAX)', 'UDF_FLOAT18': 'VARCHAR(MAX)', 'UDF_FLOAT19': 'VARCHAR(MAX)', 'UDF_DATE3': 'VARCHAR(MAX)', 'UDF_DATE4': 'VARCHAR(MAX)', 'UDF_DATE5': 'VARCHAR(MAX)', 'UDF_DATE6': 'VARCHAR(MAX)', 'UDF_DATE7': 'VARCHAR(MAX)', 'UDF_DATE8': 'VARCHAR(MAX)', 'UDF_DATE9': ...

# %% [markdown]
# # 6. Creating Index

# %%
import pyodbc
import pandas as pd

server = 'DELL\\SQLEXPRESS'
database = 'NEHADB'

connection_string = f"DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};Trusted_Connection=yes;"
conn = pyodbc.connect(connection_string)

cursor = conn.cursor()

# Query to dynamically get the primary key or unique column(s) for the table dbo.APXENRICHED_FUND
sql_get_index_column = """
SELECT c.name AS column_name
FROM sys.index_columns ic
JOIN sys.columns c ON ic.column_id = c.column_id AND ic.object_id = c.object_id
JOIN sys.indexes i ON ic.object_id = i.object_id AND ic.index_id = i.index_id
WHERE i.is_primary_key = 1 AND i.object_id = OBJECT_ID('dbo.CS_FUND');
"""

cursor.execute(sql_get_index_column)
index_column = cursor.fetchone()

if index_column:
    index_column = index_column[0]  # Fetch the column name

    # Dynamically create an index if it does not exist
    sql_create_index = f"""
    IF NOT EXISTS (
        SELECT 1 
        FROM sys.indexes 
        WHERE object_id = OBJECT_ID('dbo.CS_FUND') 
        AND name = 'Index_CF{index_column}'
    )
    BEGIN
        CREATE INDEX Index_CF{index_column}
        ON dbo.CS_FUND({index_column});
    END
    """

    cursor.execute(sql_create_index)
    conn.commit()

    # Select the first 5 records
    sql_select_head = "SELECT TOP 5 * FROM dbo.CS_FUND"
    data = pd.read_sql(sql_select_head, conn)

    # Reset index and rename the default index column
    data = data.reset_index().rename(columns={'index': 'Index'})
    print(data.head())
else:
    print("No primary key or unique index found for the table dbo.CS_FUND.")

cursor.close()
conn.close()
# Out:
#    Index ACCT_CD                                          ACCT_NAME  \
# 0      0    006x  FCA Canada Inc. Elected Master Trust (Equity)(...
# 1      1    007x  Canadian Pacific Airline Pilots' Association (...
# 2      2    008x                Grosvenor International Canada Ltd.
# 3      3    015x                             Johnson & Johnson Inc.
# 4      4    020x  Province of Newfoundland and Labrador Pooled P...
#
#   ACCT_SHT_NAME ACCT_TYP_CD PARENT_CHILD_FLAG CRRNCY_CD STATE_CD CNTRY_CD  \
# 0          NULL           F              NULL       CAD     NULL     NULL
# 1          NULL           F              NULL       CAD     NULL     NULL
# 2          NULL           F              NULL       CAD     NULL     NULL
# 3          NULL           F              NULL       CAD     NULL     NULL
# 4          NULL           F              NULL       CAD     NULL     NULL
#
#   MKT_VAL  ...  TARGET_DURATION  FACTOR_MODEL_HIERARCHY_CD  \
# 0    None  ...             NULL                       NULL
# 1    None  ...             NULL                       NULL
# 2    None  ...             NULL                       NULL
# 3    None  ...             NULL                       NULL
# 4    None  ...             NULL                       NULL
#
#   BLOCK_MONITOR_TYPE_CD LAST_MDL_CHANGE_PROCESS_DATE TARGET_CASH_PCT  \
# 0                  NULL                         NULL            NULL
# 1                  NULL                         NULL            NULL
# 2                  NULL                         NULL            NULL
# 3                  NULL                         NULL            NULL
# 4                  NULL                         NULL            NULL
#
#    DEF_STRATEGY_CHAIN_ID DEF_BENCH_TYPE3 DEF_BENCH_CD3 DEF_BENCH_ID3  \
# 0                   NULL            NULL          NULL          NULL
# 1                   NULL            NULL          NULL          NULL
# 2                   NULL            NULL          NULL          NULL
# 3                   NULL            NULL          NULL          NULL
# 4                   NULL            NULL          NULL          NULL
#
#   STRATEGY_LOT_ENABLED_IND
# 0                        N
# 1                        N
# 2                        N
# 3                        N
# 4                        N
#
# [5 rows x 419 columns]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_22712\2066358798.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(sql_select_head, conn)
